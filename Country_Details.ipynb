# %%
# !pip install countryinfo ipywidgets
# Out:
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)

# %%
from countryinfo import CountryInfo
import ipywidgets as widgets
from IPython.display import display

# %%
def get_country_info(name):
    try:
        country = CountryInfo(name)

        print("🌍 Country Name:", country.name())
        print("🏙 Capital:", country.capital())
        print("👥 Population:", country.population())
        print("📏 Area (sq km):", country.area())
        print("🌎 Region:", country.region())
        print("🗺 Subregion:", country.subregion())
        print("🧑 Demonym:", country.demonym())
        print("💱 Currency:", country.currencies())
        print("🗣 Languages:", country.languages())
        print("🚧 Borders:", country.borders())

    except Exception as e:
        print("❌ Error:", e)

# %%
country_input = widgets.Text(
    value="India",
    description="Country:"
)

button = widgets.Button(description="Get Details 🔍")

def on_click(b):
    get_country_info(country_input.value)

button.on_click(on_click)

display(country_input, button)
# Out:
# Text(value='India', description='Country:')
# Button(description='Get Details 🔍', style=ButtonStyle())
