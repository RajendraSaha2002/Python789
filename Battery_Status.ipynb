# %%
# !pip install psutil
# Out:
# Requirement already satisfied: psutil in C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages (7.2.1)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)

# %%
import psutil

# %%
def convert_time(seconds):
    if seconds == -2:
        return "Charging ⚡"
    if seconds == -1:
        return "Unknown ⏳"

    minutes, seconds = divmod(seconds, 60)
    hours, minutes = divmod(minutes, 60)
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

battery = psutil.sensors_battery()

if battery is not None:
    print("🔋 Battery Percentage :", battery.percent, "%")
    print("🔌 Power Plugged In   :", battery.power_plugged)
    print("⏱ Remaining Time     :", convert_time(battery.secsleft))
else:
    print("❌ No battery information available.")
# Out:
# 🔋 Battery Percentage : 59 %
# 🔌 Power Plugged In   : False
# ⏱ Remaining Time     : 04:07:35
