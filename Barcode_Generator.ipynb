# %%
# !pip install python-barcode pillow
# Out:
# Collecting python-barcode
#   Downloading python_barcode-0.16.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pillow in C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages (12.0.0)
# Downloading python_barcode-0.16.1-py3-none-any.whl (228 kB)
# Installing collected packages: python-barcode
# Successfully installed python-barcode-0.16.1
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\cyber\PyCharmMiscProject\.venv\Lib\site-packages)

# %%
import barcode
from barcode.writer import ImageWriter
from IPython.display import Image, display

# %%
data = "123456789012"

# Create barcode
code128 = barcode.get('code128', data, writer=ImageWriter())

# Save barcode
filename = code128.save("my_barcode")

print("✅ Barcode generated:", filename)
# Out:
# ✅ Barcode generated: my_barcode.png

# %%
display(Image(filename))
